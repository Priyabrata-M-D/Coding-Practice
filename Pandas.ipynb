# %%
import pandas as pd
df=pd.read_csv("C:\\Users\\Priyabrata\\PycharmProjects\\Guvi_project\\Churn_Modelling.csv")
df
df['Tenure']
df.head(10)
df.tail()
df.info()
df.dtypes
df.describe()
df['Age'].mean()
df['Age'].median()
df['Age'].mode()
#list
import pandas as pd
dat=[1,2,3,4]
dat
df=pd.DataFrame(dat,columns=['a'])
df
dat=[['a',1],['b',2],['c',3],['d',4]]
df=pd.DataFrame(dat,columns=['name','no'])
df
x=pd.DataFrame([9,10,12,15],columns=['dums'])
df['dums']=x['dums']
df
del df['dums']
df
y=pd.DataFrame([['e',5]], columns=['name','no'])
df.append(y)
df
import pandas as pd
df=pd.read_csv('C:\\Users\\Priyabrata\\OneDrive\\Desktop\\Python_study_Materials-main\\titanic.csv')
df

df.head()

df.tail()

df.dtypes

df[['Survived','Sex','Name']].describe()


df[['Survived','Sex','Name']]

df.columns

df
df.isnull()
df.isnull().sum()

df.shape

#df.dropna()

mean_1=df.mean()


mean_1

df.fillna(mean_1,inplace=True)

df.query('Age < 30')

#groupby

df_group=df.groupby('Sex')
df_group.ngroups

df_group.size()

df_group.Age.min()

df_group.Age.max()

df_sub=df.loc[:,['Sex','Name','Age','Fare']]
df_sub

df_sub.groupby(['Sex','Fare']).mean()

#pivot Tables

df.pivot_table('Survived', index=['Pclass','Sex'])

df.pivot_table('Survived', index=['Pclass'])

import numpy as np

df.pivot_table('Fare', index=['Pclass','Sex'], aggfunc=np.mean)
